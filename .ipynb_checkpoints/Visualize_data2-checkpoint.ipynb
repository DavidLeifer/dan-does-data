# %%
import os
import math
import numpy as np
import h5py
import glob
from tqdm import tqdm
import scipy

import keras
from keras.models import Sequential, Model
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras.layers import Embedding, Input, merge, ELU
from keras.layers.recurrent import SimpleRNN, LSTM
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import SGD, Adam, RMSprop
import sklearn.metrics as metrics

import matplotlib.pyplot as plt
# %matplotlib inline
plt.ion()

# Read in deep drive data
dfiles = glob.glob('data/*.h5')
dfiles = glob.glob('/Users/davidleifer/Desktop/DanDoesData/self-driving/train_0000.h5')
dfile = dfiles[0]
h5f = h5py.File(dfile, 'r')
A = dict(h5f.items())
plt.imshow(A['images'].value[0].swapaxes(0,2).swapaxes(0,1))

# %%
A['targets'].value[0]
# Out:
# array([-0.230168  , -1.        ,  0.57265699,  0.161715  , -0.052632  ,
#         0.40000001], dtype=float32)

# %%
A['vehicle_states'].value[:2]
# Out:
# array([[-0.131395  , -1.        ,  0.38608   ,  0.024159  , -0.052632  ,
#          0.46013099],
#        [-0.230168  , -1.        ,  0.57265699,  0.161715  , -0.052632  ,
#          0.40000001]], dtype=float32)

# %%
at = A['targets'].value[:-1]

# %%
print(at)
# Out:
# [[ -2.30168000e-01  -1.00000000e+00   5.72656989e-01   1.61715001e-01
#    -5.26320003e-02   4.00000006e-01]
#  [ -2.12800995e-01  -1.00000000e+00   6.04489982e-01   1.63610000e-02
#    -7.89470002e-02   4.05303001e-01]
#  [ -2.33034998e-01  -1.00000000e+00   6.17449999e-01   1.29600000e-02
#    -7.89470002e-02   4.08989012e-01]
#  ...,
#  [ -1.47712007e-01  -1.00000000e+00   4.64787006e-01  -9.91999987e-04
#    -5.26320003e-02   2.07433000e-01]
#  [ -1.37897000e-01  -1.00000000e+00   4.64323997e-01  -4.63000004e-04
#    -5.26320003e-02   2.12938994e-01]
#  [ -1.30060002e-01  -1.00000000e+00   4.64105994e-01  -2.18999994e-04
#    -5.26320003e-02   2.18382001e-01]]

# %%
av = A['vehicle_states'].value[1:]

# %%
at == av
# Out:
# array([[ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        ...,
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True]], dtype=bool)

# %%
False in (at == av)
# Out:
# False

# %%
set(at == av)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-64e07060461f> in <module>()
# ----> 1 set(at == av)
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
set(at == av)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-64e07060461f> in <module>()
# ----> 1 set(at == av)
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
np.sum(at == av)
# Out:
# 5988

# %%
at.shape
# Out:
# (998, 6)

# %%
998*6
# Out:
# 5988

# %%
A['images']
# Out:
# <HDF5 dataset "images": shape (999, 3, 227, 227), type "<u4">

# %%
A['targets'].value[0]
# Out:
# array([-0.230168  , -1.        ,  0.57265699,  0.161715  , -0.052632  ,
#         0.40000001], dtype=float32)

# %%
av = A['vehicle_states'].value[1:]

# %%
av
# Out:
# array([[ -2.30168000e-01,  -1.00000000e+00,   5.72656989e-01,
#           1.61715001e-01,  -5.26320003e-02,   4.00000006e-01],
#        [ -2.12800995e-01,  -1.00000000e+00,   6.04489982e-01,
#           1.63610000e-02,  -7.89470002e-02,   4.05303001e-01],
#        [ -2.33034998e-01,  -1.00000000e+00,   6.17449999e-01,
#           1.29600000e-02,  -7.89470002e-02,   4.08989012e-01],
#        ...,
#        [ -1.47712007e-01,  -1.00000000e+00,   4.64787006e-01,
#          -9.91999987e-04,  -5.26320003e-02,   2.07433000e-01],
#        [ -1.37897000e-01,  -1.00000000e+00,   4.64323997e-01,
#          -4.63000004e-04,  -5.26320003e-02,   2.12938994e-01],
#        [ -1.30060002e-01,  -1.00000000e+00,   4.64105994e-01,
#          -2.18999994e-04,  -5.26320003e-02,   2.18382001e-01]], dtype=float32)

# %%
B = np.array(A['images'].value,dtype=np.uint8)
bb = scipy.misc.imresize(B[0],(64,64),'bicubic','RGB')

# %%
bb = scipy.misc.imresize(B[0],(64,64),'bicubic','RGB')
bb.shape
# Out:
# (64, 64, 3)

# %%
plt.imshow(A['images'].value[0].swapaxes(0,2).swapaxes(0,1))

# %%
plt.imshow(bb)

# %%
bb = scipy.misc.imresize(B[0],(64,64),'cubic','RGB')

# %%
plt.imshow(bb)

# %%
bb = scipy.misc.imresize(B[0],(64,64),'cubic','RGB')

# %%
import scipy

# %%
bb = scipy.misc.imresize(B[0],(64,64),'cubic','RGB')

# %%
plt.imshow(bb)

# %%
scipy.misc.imresize?

# %%
ndata = 0
