# %%
import os
import math
import numpy as np
import h5py
import glob
from tqdm import tqdm
import scipy

import keras
from keras.models import Sequential, Model
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras.layers import Embedding, Input, merge, ELU
from keras.layers.recurrent import SimpleRNN, LSTM
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import SGD, Adam, RMSprop
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
plt.ion()
# %matplotlib inline
# Out:
# Using Theano backend.

# %%
dfiles = glob.glob('/Users/davidleifer/Desktop/DanDoesData/self-driving/data/*.h5')
dfile = dfiles[0]
h5f = h5py.File(dfile,'r')
A = dict(h5f.items())

# %%
dfiles
# Out:
# ['/Users/davidleifer/Desktop/DanDoesData/self-driving/data/train_0001.h5',
#  '/Users/davidleifer/Desktop/DanDoesData/self-driving/data/train_0002.h5',
#  '/Users/davidleifer/Desktop/DanDoesData/self-driving/data/train_0003.h5',
#  '/Users/davidleifer/Desktop/DanDoesData/self-driving/data/train_0004.h5',
#  '/Users/davidleifer/Desktop/DanDoesData/self-driving/data/train_0005.h5',
#  '/Users/davidleifer/Desktop/DanDoesData/self-driving/data/train_0006.h5',
#  '/Users/davidleifer/Desktop/DanDoesData/self-driving/data/train_0007.h5',
#  '/Users/davidleifer/Desktop/DanDoesData/self-driving/data/train_0008.h5',
#  '/Users/davidleifer/Desktop/DanDoesData/self-driving/data/train_0009.h5',
#  '/Users/davidleifer/Desktop/DanDoesData/self-driving/data/train_0010.h5']

# %%
dfile
# Out:
# '/Users/davidleifer/Desktop/DanDoesData/self-driving/data/train_0001.h5'

# %%
plt.imshow(A['images'].value[0].swapaxes(0,2).swapaxes(0,1))
AA = A['images'].value

# %%
A['targets'].value[:2]
A['vehicle_states'].value[:2]

at = A['targets'].value[:-1]
av = A['vehicle_states'].value[1:]

# slim inputs
B = np.array(A['images'].value,dtype=np.uint8)
plt.imshow(B[0][::-1,:,:].transpose((1,2,0)))

# %%
B = B[:,::-1,:,:]
bb = scipy.misc.imresize(B[0],(128,128),'cubic','RGB')
plt.imshow(bb)

# %%
bb = scipy.misc.imresize(B[0],(64,64),'cubic','RGB')
plt.imshow(bb)

# %%
speedmax = None
speedmin = None
accelmax = None
accelmin = None
for dfile in dfiles:
    with h5py.File(dfile,'r') as h5f:
        #rawr data
        A = dict(h5f.items())
        smx = np.max(A['vehicle_states'].value[:,2])
        smn = np.min(A['vehicle_states'].value[:,2])
        amx = np.max(A['vehicle_states'].value[:,3])
        amn = np.min(A['vehicle_states'].value[:,3])
        if speedmax is None or smx > speedmax:
            speedmax = smx
        if speedmin is None or smn < speedmin:
            speedmin = smn
        if accelmax is None or amx > accelmax:
            accelmax = amx
        if accelmin is None or amn < accelmin:
            accelmin = amn
        #plt.plot(A['targets'].value[:,2],A['targets'].value[:,4],'.')

# %%
throttlemax = None
throttlemin = None
steermax = None
steermin = None
for dfile in dfiles:
    with h5py.File(dfile,'r') as h5f:
        # raw data
        A = dict(h5f.items()) 
        smx = np.max(A['targets'].value[:,4])
        smn = np.min(A['targets'].value[:,4])
        tmx = np.max(A['targets'].value[:,5])
        tmn = np.min(A['targets'].value[:,5])
        if steermax is None or smx > steermax:
            steermax = smx
        if steermin is None or smn < steermin:
            steermin = smn
        if throttlemax is None or tmx > throttlemax:
            throttlemax = tmx
        if throttlemin is None or tmn < throttlemin:
            throttlemin = tmn

# %%
ndata = 0
imgsize = 64
# frame size
nrows = 64
ncols = 64

# %%
# speed, accel, distance, angle
real_in = Input(shape=(2,), name='real_input')

# video frame in, grayscale
frame_in = Input(shape=(3,nrows,ncols))

# %%
conv1 = Convolution2D(8,5,5,border_mode='same')
conv_l1 = conv1(frame_in)
Econv_l1 = ELU()(conv_l1)
pool_l1 = MaxPooling2D(pool_size=(2,2))(Econv_l1)

# %%
conv2 = Convolution2D(8,5,5,border_mode='same')
conv_l2 = conv2(pool_l1)
Econv_l2 = ELU()(conv_l2)
pool_l2 = MaxPooling2D(pool_size=(2,2))(Econv_l2)

flat = Flatten()(pool_l2)

M = merge([flat,real_in], mode='concat', concat_axis=1)

D1 = Dense(64)(M)
ED1 = ELU()(D1)
D2 = Dense(32)(ED1)
ED2 = ELU()(D2)
D3 = Dense(32)(ED2)
ED3 = ELU()(D3)

A1 = Dense(32)(ED3)
EA1 = ELU()(A1)
S1 = Dense(32)(ED3)
ES1 = ELU()(S1)

# %%
Accel = Dense(1, activation='sigmoid')(EA1)
Steer = Dense(1, activation='sigmoid')(ES1)

model = Model(input=[real_in, frame_in], output=[Accel,Steer])

model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['accuracy'])

# %%
for dfile in dfiles:
    with h5py.File(dfile,'r') as h5f:
        # raw data
        A = dict(h5f.items()) 
        # extract images in 1-byte format
        B = np.array(A['images'].value,dtype=np.float16)/255.
        # change BGR to RGB
        B = B[:,::-1,:,:]
        # Scale down image size
        imgs = np.zeros((len(B),3,64,64),dtype=np.float16)
        for i,b in enumerate(B):
            imgs[i] = scipy.misc.imresize(b,(64,64),'cubic','RGB').transpose((2,0,1))
        # speed and accel scale
        speedx = A['vehicle_states'].value[:,2:4]
        speedx[:,0] = (speedx[:,0] - speedmin) / (speedmax-speedmin)
        speedx[:,1] = (speedx[:,1] - accelmin) / (accelmax-accelmin)
        # throttle and steering scale
        targets = A['targets'].value[:,4:]

        h = model.fit([speedx, imgs], [targets[:,1], targets[:,0]],
                        batch_size = 32, nb_epoch=10, verbose=1)
# Out:
# Epoch 1/10
# 1000/1000 [==============================] - 4s - loss: 0.2053 - dense_13_loss: 0.1982 - dense_14_loss: 0.0071 - dense_13_acc: 0.0670 - dense_14_acc: 0.3160
# Epoch 2/10
# 1000/1000 [==============================] - 3s - loss: 0.1617 - dense_13_loss: 0.1546 - dense_14_loss: 0.0071 - dense_13_acc: 0.0830 - dense_14_acc: 0.3160
# Epoch 3/10
# 1000/1000 [==============================] - 3s - loss: 0.1611 - dense_13_loss: 0.1540 - dense_14_loss: 0.0071 - dense_13_acc: 0.0830 - dense_14_acc: 0.3160
# Epoch 4/10
# 1000/1000 [==============================] - 3s - loss: 0.1441 - dense_13_loss: 0.1370 - dense_14_loss: 0.0071 - dense_13_acc: 0.0750 - dense_14_acc: 0.3160
# Epoch 1/10
# 1000/1000 [==============================] - 4s - loss: 0.0321 - dense_13_loss: 0.0254 - dense_14_loss: 0.0067 - dense_13_acc: 0.0700 - dense_14_acc: 0.4510
# Epoch 2/10
# 1000/1000 [==============================] - 3s - loss: 0.0254 - dense_13_loss: 0.0187 - dense_14_loss: 0.0067 - dense_13_acc: 0.0730 - dense_14_acc: 0.4510
# Epoch 3/10
# 1000/1000 [==============================] - 3s - loss: 0.0222 - dense_13_loss: 0.0155 - dense_14_loss: 0.0067 - dense_13_acc: 0.0740 - dense_14_acc: 0.4510
# Epoch 4/10
# 1000/1000 [==============================] - 3s - loss: 0.0208 - dense_13_loss: 0.0141 - dense_14_loss: 0.0067 - dense_13_acc: 0.0740 - dense_14_acc: 0.4510
# Epoch 5/10
# 1000/1000 [==============================] - 3s - loss: 0.0195 - dense_13_loss: 0.0128 - dense_14_loss: 0.0067 - dense_13_acc: 0.0730 - dense_14_acc: 0.4510
# Epoch 6/10
# 1000/1000 [==============================] - 3s - loss: 0.0178 - dense_13_loss: 0.0111 - dense_14_loss: 0.0067 - dense_13_acc: 0.0740 - dense_14_acc: 0.4510
# Epoch 7/10
# 1000/1000 [==============================] - 3s - loss: 0.0171 - dense_13_loss: 0.0104 - dense_14_loss: 0.0067 - dense_13_acc: 0.0740 - dense_14_acc: 0.4510
# Epoch 8/10
# 1000/1000 [==============================] - 4s - loss: 0.0153 - dense_13_loss: 0.0086 - dense_14_loss: 0.0067 - dense_13_acc: 0.0740 - dense_14_acc: 0.4510
# Epoch 9/10
# 1000/1000 [==============================] - 3s - loss: 0.0139 - dense_13_loss: 0.0072 - dense_14_loss: 0.0067 - dense_13_acc: 0.0740 - dense_14_acc: 0.4510
# Epoch 10/10
# 1000/1000 [==============================] - 3s - loss: 0.0130 - dense_13_loss: 0.0063 - dense_14_loss: 0.0067 - dense_13_acc: 0.0740 - dense_14_acc: 0.4510
# Epoch 1/10
# 1000/1000 [==============================] - 3s - loss: 0.0655 - dense_13_loss: 0.0432 - dense_14_loss: 0.0223 - dense_13_acc: 0.1120 - dense_14_acc: 0.2650
# Epoch 2/10
# 1000/1000 [==============================] - 3s - loss: 0.0465 - dense_13_loss: 0.0242 - dense_14_loss: 0.0223 - dense_13_acc: 0.1120 - dense_14_acc: 0.2650
# Epoch 3/10
# 1000/1000 [==============================] - 4s - loss: 0.0405 - dense_13_loss: 0.0182 - dense_14_loss: 0.0223 - dense_13_acc: 0.1130 - dense_14_acc: 0.2650
# Epoch 4/10
# 1000/1000 [==============================] - 5s - loss: 0.0379 - dense_13_loss: 0.0157 - dense_14_loss: 0.0223 - dense_13_acc: 0.1140 - dense_14_acc: 0.2650
# Epoch 5/10
# 1000/1000 [==============================] - 4s - loss: 0.0349 - dense_13_loss: 0.0126 - dense_14_loss: 0.0223 - dense_13_acc: 0.1150 - dense_14_acc: 0.2650
# Epoch 6/10
# 1000/1000 [==============================] - 3s - loss: 0.0313 - dense_13_loss: 0.0090 - dense_14_loss: 0.0223 - dense_13_acc: 0.1150 - dense_14_acc: 0.2650
# Epoch 7/10
# 1000/1000 [==============================] - 4s - loss: 0.0304 - dense_13_loss: 0.0081 - dense_14_loss: 0.0223 - dense_13_acc: 0.1150 - dense_14_acc: 0.2650
# Epoch 8/10
# 1000/1000 [==============================] - 4s - loss: 0.0288 - dense_13_loss: 0.0065 - dense_14_loss: 0.0223 - dense_13_acc: 0.1150 - dense_14_acc: 0.2650
# Epoch 9/10
# 1000/1000 [==============================] - 4s - loss: 0.0273 - dense_13_loss: 0.0050 - dense_14_loss: 0.0223 - dense_13_acc: 0.1150 - dense_14_acc: 0.2650
# Epoch 10/10
# 1000/1000 [==============================] - 4s - loss: 0.0271 - dense_13_loss: 0.0048 - dense_14_loss: 0.0223 - dense_13_acc: 0.1150 - dense_14_acc: 0.2650
# Epoch 1/10
# 1000/1000 [==============================] - 3s - loss: 0.0368 - dense_13_loss: 0.0312 - dense_14_loss: 0.0056 - dense_13_acc: 0.1300 - dense_14_acc: 0.3520
# Epoch 2/10
# 1000/1000 [==============================] - 3s - loss: 0.0225 - dense_13_loss: 0.0169 - dense_14_loss: 0.0056 - dense_13_acc: 0.1310 - dense_14_acc: 0.3520
# Epoch 3/10
# 1000/1000 [==============================] - 3s - loss: 0.0169 - dense_13_loss: 0.0112 - dense_14_loss: 0.0056 - dense_13_acc: 0.1310 - dense_14_acc: 0.3520
# Epoch 4/10
# 1000/1000 [==============================] - 4s - loss: 0.0146 - dense_13_loss: 0.0090 - dense_14_loss: 0.0056 - dense_13_acc: 0.1310 - dense_14_acc: 0.3520
# Epoch 5/10
# 1000/1000 [==============================] - 3s - loss: 0.0129 - dense_13_loss: 0.0073 - dense_14_loss: 0.0056 - dense_13_acc: 0.1310 - dense_14_acc: 0.3520
# Epoch 6/10
# 1000/1000 [==============================] - 3s - loss: 0.0117 - dense_13_loss: 0.0061 - dense_14_loss: 0.0056 - dense_13_acc: 0.1310 - dense_14_acc: 0.3520
# Epoch 7/10
# 1000/1000 [==============================] - 3s - loss: 0.0103 - dense_13_loss: 0.0047 - dense_14_loss: 0.0056 - dense_13_acc: 0.1310 - dense_14_acc: 0.3520
# Epoch 8/10
# 1000/1000 [==============================] - 3s - loss: 0.0099 - dense_13_loss: 0.0043 - dense_14_loss: 0.0056 - dense_13_acc: 0.1310 - dense_14_acc: 0.3520
# Epoch 9/10
# 1000/1000 [==============================] - 3s - loss: 0.0093 - dense_13_loss: 0.0037 - dense_14_loss: 0.0056 - dense_13_acc: 0.1310 - dense_14_acc: 0.3520
# Epoch 10/10
# 1000/1000 [==============================] - 3s - loss: 0.0089 - dense_13_loss: 0.0033 - dense_14_loss: 0.0056 - dense_13_acc: 0.1310 - dense_14_acc: 0.3520
# Epoch 1/10
# 1000/1000 [==============================] - 4s - loss: 0.0333 - dense_13_loss: 0.0226 - dense_14_loss: 0.0107 - dense_13_acc: 0.0720 - dense_14_acc: 0.4540
# Epoch 3/10
# 1000/1000 [==============================] - 3s - loss: 0.0587 - dense_13_loss: 0.0359 - dense_14_loss: 0.0228 - dense_13_acc: 0.1260 - dense_14_acc: 0.2410
# Epoch 4/10
# 1000/1000 [==============================] - 3s - loss: 0.0540 - dense_13_loss: 0.0349 - dense_14_loss: 0.0191 - dense_13_acc: 0.1260 - dense_14_acc: 0.2450
# Epoch 5/10
# 1000/1000 [==============================] - 3s - loss: 0.0496 - dense_13_loss: 0.0323 - dense_14_loss: 0.0174 - dense_13_acc: 0.1260 - dense_14_acc: 0.2470
# Epoch 6/10
# 1000/1000 [==============================] - 3s - loss: 0.0450 - dense_13_loss: 0.0291 - dense_14_loss: 0.0159 - dense_13_acc: 0.1260 - dense_14_acc: 0.2470
# Epoch 7/10
# 1000/1000 [==============================] - 3s - loss: 0.0464 - dense_13_loss: 0.0291 - dense_14_loss: 0.0173 - dense_13_acc: 0.1260 - dense_14_acc: 0.2460
# Epoch 8/10
# 1000/1000 [==============================] - 4s - loss: 0.0419 - dense_13_loss: 0.0264 - dense_14_loss: 0.0155 - dense_13_acc: 0.1260 - dense_14_acc: 0.2470
# Epoch 9/10
# 1000/1000 [==============================] - 3s - loss: 0.0395 - dense_13_loss: 0.0248 - dense_14_loss: 0.0148 - dense_13_acc: 0.1260 - dense_14_acc: 0.2470
# Epoch 10/10
# 1000/1000 [==============================] - 3s - loss: 0.0376 - dense_13_loss: 0.0234 - dense_14_loss: 0.0142 - dense_13_acc: 0.1260 - dense_14_acc: 0.2470
# Epoch 1/10
# 1000/1000 [==============================] - 3s - loss: 0.0590 - dense_13_loss: 0.0297 - dense_14_loss: 0.0292 - dense_13_acc: 0.0280 - dense_14_acc: 0.2670
# Epoch 2/10
# 1000/1000 [==============================] - 3s - loss: 0.0445 - dense_13_loss: 0.0174 - dense_14_loss: 0.0271 - dense_13_acc: 0.0280 - dense_14_acc: 0.2680
# Epoch 3/10
# 1000/1000 [==============================] - 3s - loss: 0.0403 - dense_13_loss: 0.0133 - dense_14_loss: 0.0270 - dense_13_acc: 0.0280 - dense_14_acc: 0.2680
# Epoch 4/10
# 1000/1000 [==============================] - 3s - loss: 0.0380 - dense_13_loss: 0.0112 - dense_14_loss: 0.0268 - dense_13_acc: 0.0280 - dense_14_acc: 0.2680
# Epoch 5/10
# 1000/1000 [==============================] - 3s - loss: 0.0360 - dense_13_loss: 0.0093 - dense_14_loss: 0.0267 - dense_13_acc: 0.0280 - dense_14_acc: 0.2680
# Epoch 6/10
# 1000/1000 [==============================] - 4s - loss: 0.0342 - dense_13_loss: 0.0077 - dense_14_loss: 0.0265 - dense_13_acc: 0.0280 - dense_14_acc: 0.2690
# Epoch 7/10
# 1000/1000 [==============================] - 3s - loss: 0.0329 - dense_13_loss: 0.0066 - dense_14_loss: 0.0263 - dense_13_acc: 0.0280 - dense_14_acc: 0.2690
# Epoch 8/10
# 1000/1000 [==============================] - 4s - loss: 0.0318 - dense_13_loss: 0.0056 - dense_14_loss: 0.0262 - dense_13_acc: 0.0280 - dense_14_acc: 0.2690
# Epoch 9/10
# 1000/1000 [==============================] - 4s - loss: 0.0308 - dense_13_loss: 0.0047 - dense_14_loss: 0.0261 - dense_13_acc: 0.0280 - dense_14_acc: 0.2690
# Epoch 10/10
# 1000/1000 [==============================] - 4s - loss: 0.0301 - dense_13_loss: 0.0042 - dense_14_loss: 0.0259 - dense_13_acc: 0.0280 - dense_14_acc: 0.2690

# %%
W = model.get_weights()

# %%
W
# Out:
# [array([[[[-0.04189513, -0.04021119, -0.16215836,  0.15834373, -0.06783246],
#           [ 0.0004393 ,  0.13431653,  0.05101252,  0.20451258, -0.06712543],
#           [-0.10198504,  0.15107909,  0.03069855,  0.18584272,  0.12064467],
#           [ 0.05771311,  0.10644664,  0.04460255, -0.02748314, -0.02639531],
#           [ 0.03206084, -0.07348713,  0.12637237, -0.12609996, -0.04033113]],
#
#          [[-0.02521936,  0.02495394, -0.11177532,  0.11235642,  0.18206647],
#           [-0.02393109, -0.10397408,  0.1296691 ,  0.24320213,  0.05756497],
#           [ 0.10803273, -0.03205964, -0.03605095,  0.15297939, -0.04978864],
#           [-0.12511516, -0.04676716,  0.10471112, -0.12549798,  0.0073692 ],
#           [-0.0301367 , -0.02172283, -0.13366488,  0.07870324, -0.027456  ]],
#
#          [[ 0.14097124,  0.10602979,  0.00132026, -0.04761004,  0.08528949],
#           [-0.13502598,  0.10836539, -0.11079295,  0.13477227, -0.08692665],
#           [-0.01523522, -0.16074042, -0.02683593, -0.08668381, -0.08466703],
#           [ 0.11198165, -0.13557678,  0.09846684, -0.13706931, -0.14439699],
#           [-0.1231153 ,  0.05625517,  0.06982572, -0.10377621,  0.03541526]]],
#
#
#         [[[-0.00540074, -0.0327609 ,  0.10131629, -0.09106338, -0.07273361],
#           [-0.00191163, -0.06256532, -0.18816391, -0.03415392, -0.00496577],
#           [ 0.03573594, -0.06490646,  0.06141375, -0.04253735, -0.15442543],
#           [-0.0657132 , -0.03029859,  0.08966034, -0.07810423,  0.11614165],
#           [-0.10304943, -0.02450659,  0.01954536,  0.12655301,  0.05673695]],
#
#          [[ 0.03354118,  0.12229262,  0.0827243 , -0.05220576,  0.09454272],
#           [-0.01620555, -0.01422454, -0.12035941, -0.19535033, -0.09245887],
#           [ 0.02867753, -0.00342811, -0.0429374 , -0.12299435, -0.01807231],
#           [-0.1550936 , -0.13739094, -0.10453852, -0.12306471,  0.00095565],
#           [-0.07432079, -0.0821565 ,  0.11420829, -0.11634668,  0.05510486]],
#
#          [[ 0.02282949, -0.09637657, -0.00261674, -0.0504833 , -0.08842834],
#           [ 0.03065857, -0.07253508, -0.03770443,  0.0176009 ,  0.06647283],
#           [ 0.08336847,  0.03685567, -0.15067755, -0.0680967 ,  0.05118592],
#           [-0.03072217, -0.079666  , -0.12403255,  0.10313413,  0.08413588],
#           [-0.12843084, -0.00852724, -0.10443531, -0.07670062, -0.01967259]]],
#
#
#         [[[-0.05795563, -0.10599913,  0.09487786, -0.01430355, -0.0247841 ],
#           [ 0.05136882, -0.02262099, -0.07195905, -0.03625077,  0.01324155],
#           [ 0.0197858 , -0.07011582, -0.08924087,  0.11971413, -0.14613283],
#           [ 0.04438605,  0.09159445, -0.03557558,  0.02438401,  0.05318543],
#           [ 0.0818058 , -0.04977202, -0.09849365,  0.04847607,  0.04976586]],
#
#          [[ 0.06819367, -0.14542487, -0.04994381,  0.10751329,  0.11065289],
#           [-0.1155508 , -0.08950023,  0.10199144,  0.09392709, -0.15137145],
#           [-0.00262754,  0.03147497, -0.04596438,  0.1232046 , -0.04294999],
#           [-0.01139035,  0.05478032,  0.05764227,  0.07522305,  0.11563792],
#           [ 0.05523556, -0.01376426, -0.10464615,  0.06146039, -0.11916656]],
#
#          [[-0.14505529, -0.06000046, -0.05878409, -0.09861186,  0.11477261],
#           [ 0.05218022,  0.0466618 , -0.04555822, -0.17615095, -0.13671421],
#           [-0.07192504,  0.10181833, -0.06869277, -0.07881907,  0.05621019],
#           [-0.000435  , -0.11599693, -0.01135181, -0.12823758,  0.10123533],
#           [ 0.01773044, -0.06573827,  0.03336238,  0.05548684, -0.12977971]]],
#
#
#         [[[-0.12795669,  0.01868041, -0.15494891, -0.03847608, -0.01624119],
#           [ 0.08867651,  0.1333304 ,  0.05973591,  0.11127447,  0.14936709],
#           [ 0.05112091, -0.05355817,  0.06501976, -0.05122564, -0.01209484],
#           [ 0.12406311, -0.08401354,  0.0889558 , -0.01181983, -0.11168731],
#           [ 0.11535259,  0.15821801, -0.06100588, -0.12792805,  0.1035342 ]],
#
#          [[-0.14687049, -0.16465853, -0.0681951 , -0.15723416, -0.09736123],
#           [-0.01099609,  0.05027281, -0.01729341,  0.08732684,  0.03754925],
#           [ 0.08053757, -0.10820371, -0.11260378,  0.04162524,  0.09546597],
#           [ 0.10747401, -0.00295833, -0.15284649, -0.05176041, -0.09827733],
#           [-0.11843471,  0.08803896,  0.13396685,  0.103347  ,  0.06993303]],
#
#          [[ 0.05687032, -0.0329036 ,  0.01441113,  0.05488738, -0.0358918 ],
#           [-0.07799519, -0.03107468,  0.12641688,  0.08278529,  0.02635245],
#           [ 0.01027298, -0.15284429, -0.15766165, -0.1479229 , -0.18011621],
#           [ 0.17513791, -0.02960577, -0.10211138, -0.09138501, -0.20599616],
#           [-0.07390477,  0.08503553, -0.02687494,  0.08697306, -0.05334824]]],
#
#
#         [[[ 0.0464485 , -0.08988842,  0.04778358, -0.16479506, -0.14374948],
#           [ 0.01881629, -0.0469037 , -0.07079236, -0.05924698, -0.21179833],
#           [ 0.10875095, -0.0470829 , -0.12695542,  0.11456326, -0.14491478],
#           [-0.07447936,  0.0416532 , -0.01520957,  0.051     ,  0.09493644],
#           [ 0.04347134, -0.02392955, -0.17401536,  0.0630044 , -0.00112816]],
#
#          [[-0.06577601, -0.0023053 , -0.0912541 , -0.19091477, -0.10959207],
#           [ 0.0185746 , -0.0301214 , -0.15237124, -0.21775915, -0.09820384],
#           [ 0.11006688, -0.05024099, -0.05834864, -0.10627568,  0.11919338],
#           [ 0.09314472, -0.02749625, -0.12954779,  0.05556416,  0.03586857],
#           [-0.07071187, -0.12530363, -0.1455017 , -0.00736522, -0.08919398]],
#
#          [[ 0.01506297,  0.10194415,  0.01553435, -0.17683187, -0.03492781],
#           [-0.05290942, -0.02957729, -0.1297897 , -0.10490935, -0.1983864 ],
#           [-0.14506111,  0.01094083,  0.11359286,  0.11887162,  0.04601732],
#           [-0.07889344, -0.06979065,  0.02943767,  0.00849065,  0.05391119],
#           [-0.04670538, -0.00031658,  0.04680941, -0.10393154,  0.03785054]]],
#
#
#         [[[ 0.09406839, -0.16079926,  0.06772434,  0.05777344,  0.00738646],
#           [-0.12886478, -0.16685311, -0.01542255, -0.11976798,  0.0049649 ],
#           [-0.01673311, -0.09185144, -0.10098998, -0.11359408, -0.18019961],
#           [ 0.04617504,  0.01064316, -0.11464322, -0.19244675, -0.07776129],
#           [ 0.08757373,  0.14070652,  0.09779753,  0.06056949,  0.00677995]],
#
#          [[-0.04629543, -0.1267011 ,  0.00831201, -0.0137935 , -0.11537155],
#           [-0.10079738, -0.127508  ,  0.12416089, -0.11477865, -0.0428202 ],
#           [-0.03593672,  0.07035612, -0.04869633,  0.01187423, -0.17739502],
#           [-0.05070103,  0.12850615,  0.12607294, -0.17972679, -0.03578807],
#           [ 0.08421745,  0.12450261,  0.0886054 , -0.17440061,  0.06195256]],
#
#          [[-0.11243213, -0.08673152,  0.11510631, -0.00156525,  0.06441407],
#           [-0.0648506 , -0.05537065, -0.04236151, -0.13459601, -0.13931324],
#           [-0.08819571, -0.01856238, -0.00594235,  0.06790309,  0.06340431],
#           [ 0.02760648, -0.01794168, -0.09813295, -0.06504597,  0.07829472],
#           [ 0.09429198, -0.15131046, -0.17281348, -0.01236542, -0.06793615]]],
#
#
#         [[[-0.11703767, -0.10182352, -0.02234936, -0.10043811, -0.02285988],
#           [-0.09688444, -0.10949033, -0.08301418, -0.01470348, -0.13883515],
#           [-0.01750916, -0.13854966, -0.11475491, -0.13774502, -0.03868256],
#           [ 0.05652813, -0.07678711,  0.02171776, -0.0034909 , -0.15795723],
#           [-0.13504647,  0.01466639,  0.02449268, -0.03798463,  0.08047925]],
#
#          [[-0.16210897, -0.09565384,  0.081333  , -0.11847066,  0.1641102 ],
#           [ 0.00040647,  0.03562842, -0.11903111, -0.05591516,  0.07829195],
#           [-0.08033655, -0.15273198, -0.00967842,  0.01348516, -0.16798338],
#           [ 0.08016603,  0.051221  ,  0.02526933, -0.13717347, -0.11191404],
#           [ 0.01239049, -0.14042711, -0.07934202, -0.08708113, -0.05159449]],
#
#          [[-0.08449202, -0.01736779,  0.02169098, -0.08740172,  0.02725353],
#           [-0.08705743, -0.03999794,  0.01740122, -0.02866622, -0.09628511],
#           [-0.09204797,  0.11350331, -0.1043838 ,  0.03509381, -0.05813263],
#          [[ -6.47810921e-02,   1.24806866e-01,  -1.54987007e-01,
#              7.35728368e-02,   4.34385203e-02],
#           [ -2.02869927e-03,   1.33464128e-01,   5.70253916e-02,
#             -5.35095371e-02,  -2.71028709e-02],
#           [ -6.17768206e-02,   5.32096326e-02,   8.48064050e-02,
#              4.05879095e-02,  -6.06911862e-03],
#           [  4.11361968e-03,   3.61242965e-02,  -1.09647103e-01,
#             -2.04192009e-02,  -1.51873976e-01],
#           [ -1.14358682e-02,   5.71024083e-02,   7.96840936e-02,
#             -7.49380961e-02,  -1.32992297e-01]],
#
#          [[ -5.01900986e-02,  -4.46706712e-02,  -2.60640290e-02,
#              4.85223345e-02,  -2.25452185e-02],
#           [  1.32652432e-01,  -6.23291135e-02,   7.91401714e-02,
#             -8.80486742e-02,   1.12644516e-01],
#           [  1.44246235e-01,   1.48965433e-01,   4.67050681e-03,
#             -7.96667933e-02,   6.75968230e-02],
#           [  1.27011359e-01,   9.96406227e-02,   1.55104399e-01,
#              9.57811251e-02,  -1.23926410e-02],
#           [  9.25063267e-02,   7.92055950e-02,  -1.82641204e-02,
#              1.91270113e-02,   1.01117119e-01]],
#
#          [[ -6.05094545e-02,   1.37507200e-01,   8.86743143e-03,
#              5.74429296e-02,  -1.26580656e-01],
#           [  5.77555150e-02,   3.19653600e-02,   1.47550762e-01,
#              2.81627104e-02,  -5.78649901e-02],
#           [  1.44701660e-01,   5.33096455e-02,  -1.42317163e-02,
#              1.88228246e-02,   6.36884570e-02],
#           [ -2.61031222e-02,   1.34093329e-01,   8.21037516e-02,
#             -1.03880301e-01,  -9.02903527e-02],
#           [ -1.39451846e-01,   1.44362196e-01,  -1.15056507e-01,
#             -1.55360341e-01,   1.03469148e-01]]]], dtype=float32),
#  array([-0.03278488, -0.00816083, -0.01339778, -0.05477399, -0.02643817,
#         -0.02729088, -0.05068968, -0.06528634], dtype=float32),
#  array([[ 0.06759857, -0.02757209, -0.06387661, ...,  0.01894348,
#           0.0405837 , -0.06547406],
#         [ 0.0367582 , -0.02905977, -0.03157343, ..., -0.0016887 ,
#          -0.02667624, -0.00995883],
#         [-0.03012858,  0.04243384,  0.00501356, ..., -0.01194003,
#          -0.03379153, -0.04629243],
#         ...,
#         [-0.06243094, -0.07329875, -0.04464968, ...,  0.03289079,
#          -0.07971618,  0.01309964],
#         [-0.0863651 , -0.03076705, -0.03531078, ..., -0.01493187,
#          -0.06666726,  0.00203597],
#         [ 0.00030363, -0.00727098, -0.03302   , ..., -0.02272029,
#          -0.08554018, -0.02892348]], dtype=float32),
#  array([-0.0022979 , -0.02705543, -0.05690946, -0.02182443,  0.00136038,
#         -0.01824049,  0.00428964,  0.00203697, -0.02631588,  0.01629072,
#         -0.04599532,  0.03418774, -0.03754732, -0.04802074, -0.04660706,
#         -0.04283   , -0.0440837 , -0.01267195, -0.03282527, -0.01922175,
#          0.01203379,  0.02421878, -0.02231897, -0.03783512,  0.00729789,
#         -0.01203576, -0.00856296,  0.0213337 , -0.01270031,  0.01404115,
#         -0.03740253, -0.02524247,  0.03458523,  0.0197174 , -0.00328585,
#          0.00180584, -0.0074991 , -0.02303525, -0.07381893, -0.05092101,
#         -0.0376299 , -0.02639126,  0.01151847,  0.05852523, -0.02544714,
#         -0.00896195, -0.0160829 , -0.07951101, -0.07047628, -0.02623245,
#         -0.05553551, -0.04174799, -0.08295605, -0.05516066, -0.03283385,
#         -0.01778031, -0.01798049, -0.05676888, -0.03414148, -0.05179568,
#         -0.00229718, -0.00484887, -0.05033837, -0.03339398], dtype=float32),
#  array([[-0.13902548,  0.02394361,  0.18163507, ..., -0.26195678,
#          -0.15235829, -0.2053804 ],
#         [ 0.04954415,  0.14690998, -0.18006316, ..., -0.16250086,
#          -0.18338846, -0.08081523],
#         [ 0.02604013,  0.05334684, -0.28413579, ..., -0.03123109,
#           0.17352483,  0.17890713],
#         ...,
#         [ 0.11732239,  0.02874574, -0.00664445, ...,  0.15963125,
#          -0.1254867 ,  0.00235627],
#         [-0.21404743, -0.15987255, -0.00294463, ...,  0.10628528,
#           0.07796022,  0.02194479],
#         [-0.07982701,  0.04764772,  0.17328799, ...,  0.24332175,
#          -0.01980116, -0.15232037]], dtype=float32),
#  array([ 0.02865565, -0.05958277,  0.00503066, -0.05901584, -0.10500123,
#         -0.02745441, -0.06310349, -0.0287264 , -0.03489431, -0.00556857,
#         -0.05346636, -0.01911492, -0.04301823, -0.08488236, -0.0385209 ,
#         -0.02165145, -0.07538228, -0.04145624, -0.04905473, -0.06425723,
#         -0.05806126,  0.03884933, -0.03705636,  0.0097132 , -0.00912715,
#         -0.03646084, -0.02458334, -0.09376414,  0.02164714, -0.08639459,
#         -0.06665037, -0.06913435], dtype=float32),
#  array([[-0.20142391, -0.07020295, -0.1198151 , ..., -0.15912692,
#           0.10696538,  0.17681105],
#         [-0.07944365, -0.20549184, -0.25990796, ...,  0.06254916,
#           0.16797408, -0.31066471],
#         [-0.12813629,  0.17626075, -0.07108799, ..., -0.02395837,
#          -0.2153347 ,  0.09698003],
#         ...,
#         [-0.15867876, -0.030409  , -0.20732351, ...,  0.2033512 ,
#          -0.21707788, -0.0203202 ],
#         [-0.09306086, -0.28130436,  0.14365612, ...,  0.17862496,
#           0.20840414, -0.02391161],
#         [-0.2126103 , -0.25376031,  0.04166481, ...,  0.11332639,
#           0.26631096, -0.1683107 ]], dtype=float32),
#  array([-0.02559297, -0.02590823, -0.04593448, -0.01830258, -0.05638097,
#         -0.04062333, -0.03157011,  0.00402512, -0.00844211, -0.02774252,
#          0.01446753, -0.07021992, -0.03681597, -0.08156303,  0.01044096,
#          0.02057177, -0.11511546, -0.00129548, -0.04741727,  0.02716212,
#         -0.06555368, -0.01018653, -0.02400424,  0.02395571, -0.03184967,
#         -0.05078407, -0.12997061, -0.01229056, -0.05262449, -0.02714789,
#         -0.05927669,  0.01670717], dtype=float32),
#  array([[-0.03130388,  0.00093676, -0.28719792, ..., -0.04025991,
#          -0.1534171 ,  0.12060539],
#         [ 0.04053276,  0.07522876, -0.17805173, ..., -0.08107992,
#          -0.1523861 , -0.31100237],
#         [-0.24499029, -0.08850192,  0.26953205, ...,  0.02384363,
#           0.17155041,  0.26658809],
#         ...,
#         [-0.01224202, -0.23620535, -0.18719582, ...,  0.23302557,
#          -0.13937673,  0.18702449],
#         [-0.28346986, -0.09454861,  0.07342596, ...,  0.14428091,
#          -0.13693291, -0.19454689],
#         [ 0.12195631,  0.07525851,  0.20071185, ...,  0.07280264,
#          -0.2542538 , -0.29140607]], dtype=float32),
#  array([-0.02805638, -0.02295384,  0.01965173,  0.02470702, -0.07399889,
#         -0.00771194,  0.0096859 , -0.02786372,  0.01883104,  0.0137331 ,
#         -0.02468606, -0.04937691, -0.09261472,  0.00776655, -0.0346853 ,
#         -0.07044751,  0.01615658, -0.01868274,  0.02144194,  0.01828919,
#          0.01611659, -0.01747368, -0.07694507,  0.0061345 , -0.02091888,
#         -0.02905363, -0.04039324, -0.03872743, -0.08353184, -0.04512145,
#         -0.01676415, -0.02814214], dtype=float32),
#  array([[-0.12012847,  0.32702899, -0.24407694, ..., -0.20740536,
#          -0.08364597, -0.03919277],
#         [ 0.12071015, -0.18145776,  0.1620952 , ..., -0.10340961,
#           0.18806681, -0.32660627],
#         [ 0.04303916,  0.1551165 , -0.13365027, ...,  0.20743434,
#          -0.2523663 ,  0.27135149],
#         ...,
#         [-0.01012672, -0.24993937, -0.1617371 , ..., -0.16611759,
#          -0.08314802,  0.28196967],
#         [ 0.23938186,  0.13452041, -0.28404209, ...,  0.24076024,
#           0.24963969,  0.05559886],
#         [ 0.11265327,  0.26635611, -0.09497727, ..., -0.12705699,
#           0.00181293, -0.00777832]], dtype=float32),
#  array([ 0.07375314,  0.05007339,  0.08292486, -0.06891316, -0.0301028 ,
#          0.07505143, -0.07108516, -0.08327883,  0.05820546,  0.00708353,
#          0.05292356,  0.05915505, -0.15969282,  0.02885371, -0.07195787,
#          0.02651421,  0.05239699, -0.11956328,  0.06595055,  0.10609789,
#         -0.06655104,  0.03566574, -0.02430898, -0.07021936, -0.10769442,
#         -0.08061172, -0.20369491,  0.00943916, -0.02131659,  0.05454898,
#         -0.02113517, -0.15912971], dtype=float32),
#  array([[ 0.04245812],
#         [ 0.10010394],
#         [-0.16277388],
#         [-0.101928  ],
#         [-0.30541626],
#         [ 0.10599428],
#         [ 0.13787743],
#         [ 0.06297208],
#         [-0.2682586 ],
#         [-0.09654691],
#         [ 0.22279148],
#         [ 0.06865867],
#         [-0.06603301],
#         [ 0.15236151],
#         [-0.09152579],
#         [-0.02214446],
#         [-0.05737534],
#         [ 0.34332067],
#         [-0.26252931],
#         [-0.2023457 ],
#         [-0.20419124],
#         [-0.16672778],
#         [ 0.22901626],
#         [-0.01270727],
#         [ 0.0158502 ],
#         [-0.37511474],
#         [-0.20426607],
#         [ 0.32506076],
#         [-0.06547516],
#         [-0.03978441],
#         [-0.1423924 ],
#         [ 0.2756649 ]], dtype=float32),
#  array([-0.01787744], dtype=float32),
#  array([[ -1.83197260e-01],
#         [ -3.27940047e-01],
#         [  7.39921816e-03],
#         [  7.47567117e-02],
#         [  5.54804690e-03],
#         [ -2.68176049e-01],
#         [  2.73423016e-01],
#         [  2.46185660e-01],
#         [ -2.84303278e-01],
#         [  2.31910080e-01],
#         [ -1.75952569e-01],
#         [ -2.39505649e-01],
#         [  2.67523140e-01],
#         [ -8.75831470e-02],
#         [  1.94724828e-01],
#         [ -6.69113919e-02],
#         [ -2.62569755e-01],
#         [  3.21037412e-01],
#         [ -2.13518500e-01],
#         [ -2.74196416e-01],
#         [ -5.98525163e-03],
#         [ -1.38988165e-04],
#         [  2.45241776e-01],
#         [  2.94354975e-01],
#         [  3.22321385e-01],
#         [  2.35403970e-01],
#         [  2.43578523e-01],
#         [ -3.77174988e-02],
#         [ -1.00846344e-03],
#         [ -2.20045254e-01],
#         [  2.56128132e-01],
#         [  3.79641026e-01]], dtype=float32),
#  array([-0.06942692], dtype=float32)]

# %%
h

# %%
f, con = plt.subplots(4,3, sharex='col', sharey='row')
for row in range(4):
    for col in range(3):
        con[row,col].pcolormesh(W[0][row,col],cmap=plt.cm.hot)

# %%
# combine color channels into on filter image
f, con = plt.subplots(4,1, sharex='col', sharey='row')
for row in range(4):
    con[row].imshow(W[0][row].transpose((1,2,0)),
                    interpolation="none")

# %%
all_pred = []
for dfile in dfiles:
    with h5py.File(dfile,'r') as h5f:
        # raw data
        A = dict(h5f.items()) 
        # extract images in 1-byte format
        B = np.array(A['images'].value,dtype=np.uint8)/255.
        # change BGR to RGB
        B = B[:,::-1,:,:]
        # Scale down image size
        imgs = np.zeros((len(B),3,64,64),dtype=np.uint8)
        for i,b in enumerate(B):
            imgs[i] = scipy.misc.imresize(b,(64,64),'cubic','RGB').transpose((2,0,1))
        # speed and accel
        speedx = A['vehicle_states'].value[:,2:4]
        speedx[:,0] = (speedx[:,0] - speedmin) / (speedmax-speedmin)
        speedx[:,1] = (speedx[:,1] - accelmin) / (accelmax-accelmin)
        # throttle and steering scale
        targets = (A['targets'].value[:,4:] + 1) / 2.
        # Train while we have this file open
        h = model.predict([speedx, imgs],
                batch_size = 32, verbose=1)
        all_pred.append(h)
# Out:
# 1000/1000 [==============================] - 1s
# 1000/1000 [==============================] - 1s
# 1000/1000 [==============================] - 1s
# 1000/1000 [==============================] - 1s
# 1000/1000 [==============================] - 1s
# 1000/1000 [==============================] - 1s
# 1000/1000 [==============================] - 1s
# 1000/1000 [==============================] - 1s
# 1000/1000 [==============================] - 1s
# 1000/1000 [==============================] - 1s

# %%
plt.plot(np.array([all_pred[-1],targets[:,0]]).T,'.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-ee66f6340850> in <module>()
# ----> 1 plt.plot(np.array([all_pred[-1],targets[:,0]]).T,'.')
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1423
#    1424         for line in self._get_lines(*args, **kwargs):
# -> 1425             self.add_line(line)
#    1426             lines.append(line)
#    1427
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1706             line.set_clip_path(self.patch)
#    1707
# -> 1708         self._update_line_limits(line)
#    1709         if not line.get_label():
#    1710             line.set_label('_line%d' % len(self.lines))
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1728         Figures out the data limit of the given line, updating self.dataLim.
#    1729         """
# -> 1730         path = line.get_path()
#    1731         if path.vertices.size == 0:
#    1732             return
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in get_path(self)
#     923         """
#     924         if self._invalidy or self._invalidx:
# --> 925             self.recache()
#     926         return self._path
#     927
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in recache(self, always)
#     619                 y = ma.asarray(yconv, np.float_).filled(np.nan)
#     620             else:
# --> 621                 y = np.asarray(yconv, np.float_)
#     622             y = y.ravel()
#     623         else:
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     480
#     481     """
# --> 482     return array(a, dtype, copy=False, order=order)
#     483
#     484 def asanyarray(a, dtype=None, order=None):
#
# ValueError: setting an array element with a sequence.

# %%
plt.plot(np.array([all_pred[-1].reshape(1000),targets]).T,'.')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-5809b093a08c> in <module>()
# ----> 1 plt.plot(np.array([all_pred[-1].reshape(1000),targets]).T,'.')
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
plt.plot(np.array([all_pred[-1],targets]).T,'.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-1efb132ac351> in <module>()
# ----> 1 plt.plot(np.array([all_pred[-1],targets]).T,'.')
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1423
#    1424         for line in self._get_lines(*args, **kwargs):
# -> 1425             self.add_line(line)
#    1426             lines.append(line)
#    1427
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1706             line.set_clip_path(self.patch)
#    1707
# -> 1708         self._update_line_limits(line)
#    1709         if not line.get_label():
#    1710             line.set_label('_line%d' % len(self.lines))
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1728         Figures out the data limit of the given line, updating self.dataLim.
#    1729         """
# -> 1730         path = line.get_path()
#    1731         if path.vertices.size == 0:
#    1732             return
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in get_path(self)
#     923         """
#     924         if self._invalidy or self._invalidx:
# --> 925             self.recache()
#     926         return self._path
#     927
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in recache(self, always)
#     619                 y = ma.asarray(yconv, np.float_).filled(np.nan)
#     620             else:
# --> 621                 y = np.asarray(yconv, np.float_)
#     622             y = y.ravel()
#     623         else:
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     480
#     481     """
# --> 482     return array(a, dtype, copy=False, order=order)
#     483
#     484 def asanyarray(a, dtype=None, order=None):
#
# ValueError: setting an array element with a sequence.

# %%
def get_point(s,start=0,end=63,height= 48):
    X = int(s*(end-start))
    if X < start:
        X = start
    if X > end:
        X = end
    return (X,height)

# %%
from PIL import Image, ImageDraw
import matplotlib.animation as animation

# %%
figure = plt.figure()

# %%
figure

# %%
imageplot = plt.imshow(np.zeros((64, 64, 3), dtype=np.uint8))

# %%
def next_frame(i):
    im = Image.fromarray(np.array(imgs[i].transpose(1,2,0),dtype=np.uint8))
    draw = ImageDraw.Draw(im)
    draw.line((21,48, 21,all_pred[-1][i]*48),
             fill=(0,255,0,128))
    draw.line((42,48, 42,targets[i]*48),
             fill=(0,255,0,128))
    imageplot.set_array(im)
    return imageplot,
animate = animation.FuncAnimation(figure, next_frame, frames=range(len(imgs)), interval=100, blit=False)
plt.show()

# %%
for datafile in dfiles[-1:]:
    with h5py.File(datafile) as data:
        figure = plt.figure()
        imageplot = plt.imshow(np.zeros((64, 64, 3), dtype=np.uint8))
        def next_frame(i):
            im = Image.fromarray(np.array(imgs[i].transpose(1,2,0),dtype=np.uint8))
            draw = ImageDraw.Draw(im)
            draw.line((21,48, 21,all_pred[-1][i]*48),
                     fill=(0,255,0,128))
            draw.line((42,48, 42,targets[i]*48),
                     fill=(0,255,0,128))
            imageplot.set_array(im)
            return imageplot,
        animate = animation.FuncAnimation(figure, next_frame, frames=range(len(imgs)), interval=100, blit=False)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only length-1 arrays can be converted to Python scalars
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     337                 pass
#     338             else:
# --> 339                 return printer(obj)
#     340             # Finally look for special method names
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     226
#     227     if 'png' in formats:
# --> 228         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     229     if 'retina' in formats or 'png2x' in formats:
#     230         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     117
#     118     bytes_io = BytesIO()
# --> 119     fig.canvas.print_figure(bytes_io, **kw)
#     120     data = bytes_io.getvalue()
#     121     if fmt == 'svg':
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2178                     orientation=orientation,
#    2179                     dryrun=True,
# -> 2180                     **kwargs)
#    2181                 renderer = self.figure._cachedRenderer
#    2182                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     525
#     526     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 527         FigureCanvasAgg.draw(self)
#     528         renderer = self.get_renderer()
#     529         original_dpi = renderer.dpi
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1163
#    1164         self._cachedRenderer = renderer
# -> 1165         self.canvas.draw_event(renderer)
#    1166
#    1167     def draw_artist(self, a):
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/backend_bases.py in draw_event(self, renderer)
#    1807         s = 'draw_event'
#    1808         event = DrawEvent(s, self, renderer)
# -> 1809         self.callbacks.process(s, event)
#    1810
#    1811     def resize_event(self):
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     561             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     562                 try:
# --> 563                     proxy(*args, **kwargs)
#     564                 except ReferenceError:
#     565                     self._remove_proxy(proxy)
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     428             mtd = self.func
#     429         # invoke the callable and return the result
# --> 430         return mtd(*args, **kwargs)
#     431
#     432     def __eq__(self, other):
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/animation.py in _start(self, *args)
#     646
#     647         # Now do any initial draw
# --> 648         self._init_draw()
#     649
#     650         # Add our callback for stepping the animation and
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/animation.py in _init_draw(self)
#    1191         # artists.
#    1192         if self._init_func is None:
# -> 1193             self._draw_frame(next(self.new_frame_seq()))
#    1194
#    1195         else:
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1210         # Call the func with framedata and args. If blitting is desired,
#    1211         # func needs to return a sequence of any artists that were modified.
# -> 1212         self._drawn_artists = self._func(framedata, *self._args)
#    1213         if self._blit:
#    1214             for a in self._drawn_artists:
#
# <ipython-input-86-4424bdb211f3> in next_frame(i)
#       7             draw = ImageDraw.Draw(im)
#       8             draw.line((21,48, 21,all_pred[-1][i]*48),
# ----> 9                      fill=(0,255,0,128))
#      10             draw.line((42,48, 42,targets[i]*48),
#      11                      fill=(0,255,0,128))
#
# /Users/davidleifer/anaconda/lib/python3.5/site-packages/PIL/ImageDraw.py in line(self, xy, fill, width)
#     177         ink, fill = self._getink(fill)
#     178         if ink is not None:
# --> 179             self.draw.draw_lines(xy, ink, width)
#     180
#     181     ##
#
# SystemError: <built-in method draw_lines of ImagingDraw object at 0x111254c90> returned a result with an error set
